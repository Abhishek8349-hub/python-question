# %% [markdown]
# 1. Print the result of 25 + 75.
# 2. Print the result of 50 - 18.
# 3. Create two variables a = 15 and b = 5. Print their sum.
# 4. Create two variables x = 20 and y = 4. Print their division.
# 5. Create variables length = 10 and width = 6. Calculate and print the perimeter of a rectangle.
# 6. Create variable price = 250 and quantity = 3. Print total cost.
# 7. Calculate and print the square of 12. Add a comment explaining the code.
# 8. Write multi line comment (Hello;This is a multi-line comment;Bye) and print Hello
# 9. Print your name, surname, hobby, weight, No. of siblings in a form of paragraph.
# 10. what will be the output of (2 + 3 * 4) and ((2 + 3) * 4)

# %%
# print the result of 25 + 75

num1 = 25
num2 = 75 

result = num1 + num2 
print(result)

# %%
#print the result of 50 - 18
num1 = 50
num2 = 18

Answer = num1 - num2
print(Answer)

# %%
# Create two variables a = 15 and b = 5. Print their sum.
a = 15
b = 5
sum = a+b
print("sum is :",sum)

# %%
# Create two variables x = 20 and y = 4. Print their division.

x = 20
y = 4
div = x/y

print("division : ",div)

# %%
#Create variables length = 10 and width = 6. Calculate and print the perimeter of a rectangle.
# formula of rec of premimeter = 2*(l+B)

length = 10

width = 6

perimeter = 2*(length + width)

print("perimeter of rectangle is :",perimeter)

# %%
#Create variable price = 250 and quantity = 3. Print total cost

price = 250 
quantity = 3

total_cost =  price*quantity

print("total cost of product is :",total_cost)

# %%
#Calculate and print the square of 12. Add a comment explaining the code.
num = 12  # we create a variable 
          

square = num*num   # square of number means multiply by itself  and  calcualte the square

print("square of 12 is :",square) # print statement show the result

# %%
# Write multi line comment (Hello;This is a multi-line comment;Bye) and print Hello

'''
hello
this is a multi-line comment 
bye

'''
print("hello")

# %%
#Print your name, surname, hobby, weight, No. of siblings in a form of paragraph

name = "Abhishek"
surname = "Patidar"
hobby = "coding"
weight = 68
sibling = 1

print("my name is",name,surname +"."
      "my hobby is",hobby +"."
      "my wieght is",str(weight) +"."
     "and have",sibling,"sibling " )

# %%
#what will be the output of (2 + 3 * 4) and ((2 + 3) * 4)


case1 = (2 + 3 *4 )
case2 = ((2+3) * 4)
print(f'{case1}\n{case2}')

# %%
print((2 + 3 * 4)and((2 + 3)*4))

# %%
a = 10
b = 21.50
c = 2+3j
d = "Abhishek patidar"
e = ('apple','banana','cat',2)
f = [1,3,4,'a']
g = {1,3,3,4,5,6}
h = {"A":['abhi','vineet','Anshul'],
     "B":(1,3,4,5),"c":10}

print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
print(e,type(e))
print(f,type(f))
print(g,type(g))
print(h,type(h))

# %% [markdown]
# python - day 2 question
# 1. Write a program to print Hello, Python!
# 2. Print your name, age, and city using a single print() statement.
# 3. Print the following pattern:
#     *
#     **
#     ***
#     ****
# 4. Find the Area of rectangle
# 5. Write a python program to calculate addtion of 3 numbers
# 6. Print the below words in each line using a single print function
#    Python
#    is
#    Fun
# 7. Create variables of the following types and print them with their types:
# Integer, Float, String, Boolean, Complex number.
# 8. Write a program that checks the type of: x = True, y = None
# 9. Predict the output:  print(type(type(5)))
# 10. Store your roll number and percentage, then print them in one line.
# 11. Swap the values of 2 variables with/without using the 3rd variable

# %%
# . Write a program to print Hello, Python!
print("Hello")

# %%
#2. Print your name, age, and city using a single print() statement.
name = "Abhishek Patidar"
age = 21 
city = "sarangpur"

print("Myname is :",name ,"age is :",age , "and city is ",city)

# %%
'''3. Print the following pattern:
    *
    **
    ***
    ****
    '''

print("*\n* * \n* * * \n* * * *   \n* * * * *")

# %%
#Find the Area of rectangle
l = eval(input("enter a length:"))
w = eval(input("enter a width:"))

square = l*w
print("square of rectangle is :",square)

# %%
num1 = eval(input("enter a 1st no:"))
num2 = eval(input("enter a 2nd no:"))
num3 = eval(input("enter a 3rd no:"))

addtion = num1+num2+num3
print("answer is :",addtion)

# %%
""". Print the below words in each line using a single print function
   Python
   is 
   Fun
"""

print("python\nis\nfun")
# Out:
# python
# is
# fun

# %%
#7. Create variables of the following types and print them with their types:
#Integer, Float, String, Boolean, Complex number.

num1 =10
num2 = 22.5
name = 'Abhi'
val =  4
val= True

num3= 2+1j
print(type(num1),num1)
print(type(num2),num2)
print(type(num3),num3)
print(type(val),val)
# Out:
# <class 'int'> 10
# <class 'float'> 22.5
# <class 'complex'> (2+1j)
# <class 'bool'> True

# %%
#8. Write a program that checks the type of: x = True, y = None
x = True
y = None
print(type(x),x)
print(type(y),y)
# Out:
# <class 'bool'> True
# <class 'NoneType'> None

# %%
#. Predict the output:  print(type(type(5)))
# reault :<class 'type'>  because class 0f 5 is int and type()again s0 every object is class 0f "type"

# %%
 #Store your roll number and percentage, then print them in one line.

roll_no = 49 
percentage = 81

print("my roll no is :",roll_no,"and percentage is :",percentage)
# Out:
# my roll no is : 49 and percentage is : 81

# %%
#11. Swap the values of 2 variables with/without using the 3rd variable

a =10
b =20

a,b=b,a
print("swap of two no:",a,b)

#with 3rd var
a = 10
b= 20

c=a

a=b
b=c
print(a,b)
# Out:
# swap of two no: 20 10
# 20 10
